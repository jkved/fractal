# %%
import numpy as np
import matplotlib.pyplot as plt
import fractal as fractalLibrary

# %%
Roots = np.array([-1-1j, 1-1j, 0+np.sqrt(2)*1j])

fractal = fractalLibrary.NewtonRaphson(Roots)
graph = fractal.plotFractal()

# %%
mb = Mandelbrot()
mb.plotFractal()
# Out:
# <ipython-input-83-4d7dbaf5e01e>:16: RuntimeWarning: overflow encountered in cdouble_scalars
#   return z**self.n + c
# <ipython-input-83-4d7dbaf5e01e>:16: RuntimeWarning: invalid value encountered in cdouble_scalars
#   return z**self.n + c
# <ipython-input-83-4d7dbaf5e01e>:26: RuntimeWarning: invalid value encountered in double_scalars
#   if (z.real + z.imag >= lim):
